# %%
def divideNumber(number):
    return number / 2

# %%
divideNumber(88)
# Out:
# 44.0

# %%
myList=[3,5,7,9,11]

# %%
myResulList=[] 
for num in myList:
    myResulList.append(divideNumber(num))  
    print(myResulList)
# Out:
# [1.5]
# [1.5, 2.5]
# [1.5, 2.5, 3.5]
# [1.5, 2.5, 3.5, 4.5]
# [1.5, 2.5, 3.5, 4.5, 5.5]

# %% [markdown]
# # map

# %%
help(map)
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(function, iterable, /, *iterables)
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(self, /)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
map(divideNumber, myList)

# %%
list(map(divideNumber, myList))
# Out:
# [1.5, 2.5, 3.5, 4.5, 5.5]

# %%
def controlSting(string):
    return "Batuhan" in string

# %%
controlSting("My name is Batuhan")
# Out:
# True

# %%
myStringList = ["My name is Batuhan", "I am learning Python", "I love AI", "Batuhan"]
list(map(controlSting, myStringList))
# Out:
# [True, False, False, True]

# %% [markdown]
# # Filter

# %%
list(filter(controlSting, myStringList))
# Out:
# ['My name is Batuhan', 'Batuhan']

# %% [markdown]
# # Lambda

# %%
multiplyLambda = lambda num: num * 3

# %%
type(multiplyLambda)
# Out:
# function

# %%
multiplyLambda(30)
# Out:
# 90

# %%
result=multiplyLambda(30)
print(result)
# Out:
# 90

# %%
def multiply(num):
    return num * 3

# %%
list(map(lambda num:num/4, myList ))
# Out:
# [0.75, 1.25, 1.75, 2.25, 2.75]

# %% [markdown]
# # Scope

# %%
x= 20
def multiply(num):
    x=5
    return num * x

# %%
multiply(15)
# Out:
# 75

# %%
x
# Out:
# 20

# %%
x= 20 # Global variable
def multiply(num):
    return num * x # Global variable

# %% [markdown]
# # LEGB -> L->Local, E->enclosing, G->global, B->built-in

# %%
# Global
myString = "Batu"

def myFunction():
    myString = "Batu2"
    
    def my_function2():
        myString = "Batu3"
        print(myString)
    my_function2()

# %%
myString
# Out:
# 'Batu'

# %%
myFunction()
# Out:
# Batu3

# %%
y=10
def newFunction(y):
    print(y)
    y=5
    print(y)    
    return y

# %%
newFunction(30)
# Out:
# 30
# 5
# 5

# %%
y=10
def changeY():
    global y
    print(y)
    y=5
    print(y)    
    return y

# %%
changeY()
# Out:
# 10
# 5
# 5

# %%
y
# Out:
# 5
