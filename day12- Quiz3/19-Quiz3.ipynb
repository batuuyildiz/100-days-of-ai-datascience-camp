# %%
#1) What will be the output of the following code?

# %%
def toplama(a,b):
    print(a,b)

# %%
'''
x = toplama(3,4)
print(x)
'''
# Out:
# '\nx = toplama(3,4)\nprint(x)\n'

# %%
# None

# %%
#2) What will be the output of the following code?

# %%
def usselIslem(x=5,y=3):
    print(x ** y)

# %% [markdown]
# usselIslem(2,4)

# %%
# 16

# %%
#3) What will be the output if we call the same function as follows?

# %% [markdown]
# usselIslem()

# %%
# Answer 125

# %%
#4) What will be the output of the following code?

# %%
def myLoop(*args):
    for element in args:
        print(element / 2)

# %% [markdown]
# myLoop(3,2,1,5,3,4)

# %%
# Answer 1.5 ,1 , 0.5 , 2.5 , 1.5 , 2

# %%
#5) Pass the numbers specified in the following array to the myFunction function and create a new array.

# %%
def myFunc(num):
    return num ** 3

# %%
myList = [2,3,4,5,6]

# %%
# Answer list(map(myFunc, myList))

# %%
# Answer

# %%
#6) Create a new list that will display only barcodes containing XYZ in the following string array.

# %%
barkodDizisi = ["ABC231","SA3123XYZ","XYZA123Q","QRE1231KJ","X112QGL"]

# %%
# Answer = list(filter(lambda x: 'XYZ' in x, barkodDizisi))

# %%
# Answer

# %%
#7)  If you read the code below, what will the print statement at the bottom print when the exampleFunction is executed?

# %%
myVar = "Atil Samancioglu"

def ornekFonksiyon():
    myVar = "Atil"
    
    def digerFonksiyon():
        print(myVar)
    
    digerFonksiyon()

# %%
ornekFonksiyon()
# Out:
# Atil

# %%
# Answer Atil

# %%
#8) When you examine the class printed below, what will be the output of the kedim.yasiCarp() code?

# %%
class Kedi():
        
    def __init__(self,isim,yas=5):
        self.isim = isim
        self.yas = yas
        
    def yasiCarp(self):
        return self.yas * 3

# %%
kedim = Kedi("Tonton")

# %%
#kedim.yasiCarp()

# %%
# Answer. 15

# %%
#9) What will be the output of the following code?

# %%
class Ogrenci():
    
    def __init__(self,isim,sinavNotu):
        self.isim = isim
        self.__sinavNotu = sinavNotu
    
    def notuGoster(self):
        print(f"{self.isim} sınav notu: {self.__sinavNotu}")

# %%
ogrenci = Ogrenci("Mehmet",85)

# %%
ogrenci.__sinavNotu = 75

# %%
#ogrenci.notuGoster()

# %%
# Answer 85

# %%
#10) Enables us to create abstract classes and methods, allowing us to write our code in a more organized manner.

# %%
# What is the name of the OOP principle that can also benefit us structurally in large projects?

# %%
# Answer = Abstraction
