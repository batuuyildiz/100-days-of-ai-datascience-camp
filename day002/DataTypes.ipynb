# %% [markdown]
# # Numeric types

# %%
x = 10        # int

# %%
y = 3.14      # float

# %%
z = 2 + 3j    # complex

# %% [markdown]
# # String

# %%
name = "Batuhan"

# %% [markdown]
# # Boolean

# %%
is_learning = True

# %% [markdown]
# # List

# %%
fruits = ["apple", "banana", "cherry"]

# %% [markdown]
# # Tuple

# %%
coordinates = (41.0, 29.0)

# %% [markdown]
# # Set

# %%
unique_numbers = {1, 2, 3, 3, 2}  # duplicates removed → {1, 2, 3}

# %% [markdown]
# # Dictionary

# %%
student = {"name": "Batuhan", "age": 30, "field": "AI"}

# %%
print(type(x), type(name), type(fruits), type(student))
# Out:
# <class 'int'> <class 'str'> <class 'list'> <class 'dict'>
