# %%
import numpy as np

# %%
import pandas as pd

# %%
grades = {"James" : 50, "Lars": 60, "Kirk" : 55, "Rob" : 65}

# %%
pd.Series(grades)
# Out:
# James    50
# Lars     60
# Kirk     55
# Rob      65
# dtype: int64

# %%
names=["James" , "Lars" ,"Kirk", "Rob" ]

# %%
pd.Series(names)
# Out:
# 0    James
# 1     Lars
# 2     Kirk
# 3      Rob
# dtype: object

# %%
grades=[10,50,70,30]

# %%
pd.Series(grades)
# Out:
# 0    10
# 1    50
# 2    70
# 3    30
# dtype: int64

# %%
pd.Series(grades,names)
# Out:
# James    10
# Lars     50
# Kirk     70
# Rob      30
# dtype: int64

# %%
pd.Series(data=grades,index=names)
# Out:
# James    10
# Lars     50
# Kirk     70
# Rob      30
# dtype: int64

# %%
#with numpy

# %%
numpy_array=np.array([50,40,30,20])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    40
# 2    30
# 3    20
# dtype: int64

# %%
#arithmetic

# %%
contest_result=pd.Series(data=[10,5,100],index=["Batuhan","James","Jack"])

# %%
contest_result2=pd.Series(data=[20,50,10],index=["Batuhan","James","Jack"])

# %%
contest_result
# Out:
# Batuhan     10
# James        5
# Jack       100
# dtype: int64

# %%
contest_result2
# Out:
# Batuhan    20
# James      50
# Jack       10
# dtype: int64

# %%
contest_result["Batuhan"]
# Out:
# np.int64(10)

# %%
final_result=contest_result+contest_result2

# %%
final_result
# Out:
# Batuhan     30
# James       55
# Jack       110
# dtype: int64

# %%
different_series=pd.Series([20,30,40,50],["a","b","c","d"])

# %%
different_series2=pd.Series([70,60,25,95],["a","c","f","g"])

# %%
different_series+different_series2
# Out:
# a     90.0
# b      NaN
# c    100.0
# d      NaN
# f      NaN
# g      NaN
# dtype: float64
