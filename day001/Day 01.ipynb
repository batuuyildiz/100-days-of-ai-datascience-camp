# %%
# Day 01 - Introduction to Data Science and Machine Learning

# =========================
# 1. Introduction
# =========================
# In this notebook, I will start my 100-day journey into Data Science & Machine Learning.
# The goal is to set up the environment and understand the basic concepts.

# %%
print("Welcome to Day 01 of AI & Data Science Camp!")
# Out:
# Welcome to Day 01 of AI & Data Science Camp!

# %%
# =========================
# 2. Python Warm-up
# =========================
# Let's test if Python environment is ready.

# %%
a = 5
b = 10
print("Sum of a + b =", a + b)
# Out:
# Sum of a + b = 15

# %%
# =========================
# 3. First Steps with Strings
# =========================

# %%
name = "batuhan yildiz"
print("Original:", name)
print("Uppercase:", name.upper())
print("Count of 'a':", name.count("a"))
# Out:
# Original: batuhan yildiz
# Uppercase: BATUHAN YILDIZ
# Count of 'a': 2

# %%
# =========================
# 4. Reflection
# =========================
# Today I started my journey, installed my environment, and wrote my first Python code in this camp.
