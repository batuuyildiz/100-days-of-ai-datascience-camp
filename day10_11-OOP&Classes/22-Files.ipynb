# %%
# %%writefile myfile.txt
# test 1
# test 2
# test 3
# Out:
# Writing myfile.txt

# %%
myFile = open("myfile.txt")

# %%
type(myFile)
# Out:
# _io.TextIOWrapper

# %%
myFile.read()
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myFile.read()
# Out:
# ''

# %%
myFile.seek(0) # Move the cursor back to the beginning of the file
# Out:
# 0

# %%
myFile.read()
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myFile.close()

# %%
# with open("myfile.txt") as myFile:

# %%
with open("myfile.txt") as myFile:
    myContent = myFile.read()

# %%
myContent
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myContent
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
with open("myfile.txt",mode="w") as myNewFile: # w = write mode
    myNewFile.write("This is a new line")

# %%
# w-> write mode
# r-> read mode
# a-> append mode
# r+ -> read and write mode

# %%
with open("myfile.txt",mode="a") as myNewFile3:
    myNewFile3.write("\nThis is an appended line")

# %%
with open("myfile.txt",mode="r") as myNewFile4:
    myContent2 = myNewFile4.read()

# %%
myContent
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myContent2
# Out:
# 'This is a new line\nThis is an appended line'
