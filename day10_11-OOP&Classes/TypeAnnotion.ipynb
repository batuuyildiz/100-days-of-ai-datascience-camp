# %%
name:str = "Batuhan"

# %%
type(name)
# Out:
# str

# %%
surname : str = 20

# %%
type(surname) # it should be str but it is int
# Out:
# int

# %%
name : str = "Batuhan" # string type
age : int = 25 # in years
height : float = 1.75 # in meters
is_student : bool = True # True or False

# %%
def add_numbers(a: int, b: int) -> int:
    return a + b

# %%
add_numbers(5, 10)
# Out:
# 15

# %%
def process_value(value: int | str) -> str:
    if isinstance(value, int):
        return f"Processed integer: {value}"
    else:
        return f"Processed string: {value}"

# %%
process_value(100)
# Out:
# 'Processed integer: 100'

# %%
process_value("abc")
# Out:
# 'Processed string: abc'
