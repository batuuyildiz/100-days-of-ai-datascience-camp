# %%
age = input("What is your age? ") # This will cause an error if input is not a number

# %%
age
# Out:
# '30'

# %%
int(age)*2
# Out:
# 60

# %%
# Try - except block

# %%
while True:

    try:
        myAge=int(input("What is your age? "))
        print(myAge*2)
        
    except ValueError:
        print("Enter your age in numbers only")
    else:
        print("Thank you")
        break
    finally:
            print("---End of try-except block---")
# Out:
# 60
# Thank you
# ---End of try-except block---
