# %%
myString = "Hello python"

# %%
myString.split()
# Out:
# ['Hello', 'python']

# %%
type(myString.split()) # check the type of the result
# Out:
# list

# %% [markdown]
# # List

# %%
myString
# Out:
# 'Hello python'

# %%
myString[0]  # Accessing the first character
# Out:
# 'H'

# %%
#myString[0]="a"  # This will raise an error because strings are immutable!

# %%
myList = [1, 2, 3, 4, 5]

# %%
type(myList)  # Check the type of the list
# Out:
# list

# %%
x=10
y=20
z=30

# %%
myList=[x, y, z]  # Creating a list with variables

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList[0]
# Out:
# 10

# %%
myList[0]= 100  # Modifying the first element of the list

# %%
#mutable

# %%
len(myList)  # Length of the list
# Out:
# 3

# %%
myList.append(40)  # Adding an element to the end of the list

# %%
myList
# Out:
# [100, 20, 30, 40]

# %%
myList.append("ABC")

# %%
myList
# Out:
# [100, 20, 30, 40, 'ABC']

# %%
myList.count(10)  # Counting occurrences of an element in the list
# Out:
# 0

# %%
myList.count(40)
# Out:
# 1

# %%
myList.index(30)  # Finding the index of an element in the list
# Out:
# 2

# %%
myList.insert(1, 50)  # Inserting an element at a specific index

# %%
myList
# Out:
# [100, 50, 20, 30, 40, 'ABC']

# %%
myList.pop()  # Removing and returning the last element of the list
# Out:
# 'ABC'

# %%
myList
# Out:
# [100, 50, 20, 30, 40]

# %%
myList.remove(50)  # Removing a specific element from the list

# %%
myList
# Out:
# [100, 20, 30, 40]

# %%
myList.sort()

# %%
myList
# Out:
# [20, 30, 40, 100]

# %%
x=input("Enter a number: ")  # Taking input from the user

# %%
x
# Out:
# '102'

# %%
x * 2  # Multiplying the input by 2
# Out:
# '102102'

# %%
type(x)
# Out:
# str

# %%
myInteger = 50

# %%
str(myInteger)  # Converting integer to string
# Out:
# '50'

# %%
float(myInteger)  # Converting integer to float
# Out:
# 50.0

# %%
myString = "Hello python"

# %%
# int(myString)  # This will raise an error because strings cannot be converted to integers

# %%
mixList = ["Alice", "Bob", "Charlie",5,6,22, "David"]

# %%
type(mixList)
# Out:
# list

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]

# %%
list1+list2  # Concatenating two lists
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
str(list1) + str(list2)  # Concatenating two lists as strings
# Out:
# '[1, 2, 3][4, 5, 6]'

# %% [markdown]
# # Advanced List

# %%
mixedList= [1, "Hello", 3.14, True,"BaTUhanYildiz", 5 , [1, 2, 3],]

# %%
mixedList
# Out:
# [1, 'Hello', 3.14, True, 'BaTUhanYildiz', 5, [1, 2, 3]]

# %%
type(mixedList[0])
# Out:
# int

# %%
type(mixedList[5])  # Checking the type of the sixth element
# Out:
# int

# %%
type(mixedList)  # Checking the type of the first element
# Out:
# list

# %% [markdown]
# ## nestedList

# %%
myNestedList = [1, 2, [3, 4], [5, 6, [7, 8]],"batu",5,4,88651426]

# %%
mynestedList[0]
# Out:
# 1

# %%
mynestedList[3]
# Out:
# [5, 6, [7, 8]]

# %%
smallList = myNestedList[3]  # Accessing the fourth element which is a list

# %%
smallList
# Out:
# [5, 6, [7, 8]]

# %%
smallList[2]
# Out:
# [7, 8]

# %%
smallList[2][0] # Accessing the first element of the nested list
# Out:
# 7

# %%
lastList = [9, [10, 11, "Abcded"], 12]

# %%
lastList[1][2]  # Accessing the third element of the second nested list
# Out:
# 'Abcded'

# %%
firstList = [10, 20, 30, 40, 50]

# %%
firstList[::2]
# Out:
# [10, 30, 50]
