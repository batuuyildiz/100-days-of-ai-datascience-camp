# %% [markdown]
# # 1) What will be the output of the following code?

# %%
x = 5
y = 3
z = 6

# %% [markdown]
# x > y and z > x

# %%
# Answer
True
# Out:
# True

# %% [markdown]
# # 2) What will be the output if the code is changed with the same values?

# %% [markdown]
# x < y or z > y

# %%
# Answer
True
# Out:
# True

# %% [markdown]
# # 3) What will be the output of the following code?

# %%
'''
yas = 20

if yas < 18:
    print("18 yaşından küçüksünüz")
elif yas >= 18 and yas < 30:
    print("18 ile 30 yaş arasında bir gençsiniz")
elif yas >= 30 and yas < 40:
    print("30 ve 40 arasına gelmişsiniz")
else:
    print("40 yaşından daha büyüksünüz")
'''
# Out:
# '\nyas = 20\n\nif yas < 18:\n    print("18 yaşından küçüksünüz")\nelif yas >= 18 and yas < 30:\n    print("18 ile 30 yaş arasında bir gençsiniz")\nelif yas >= 30 and yas < 40:\n    print("30 ve 40 arasına gelmişsiniz")\nelse:\n    print("40 yaşından daha büyüksünüz")\n'

# %%
# Answer
print("18 ile 30 yaş arasında bir gençsiniz")
# Out:
# 18 ile 30 yaş arasında bir gençsiniz

# %% [markdown]
# # 4) In the dictionary below, write an if condition that shows whether the letter c appears in the values.

# %%
my_dictionary = {"k1":10,"k2k":"a","k32":30,"k4":"c"}

# %%
# Answer
for key, value in my_dictionary.items():
    if value == "c":
        print("element c is found")
    else:
        print("element c is not found")
# Out:
# element c is not found
# element c is not found
# element c is not found
# element c is found

# %%
# Answer

# %% [markdown]
# # 5) In the dictionary below, write an if condition that shows whether the letter a appears in the keys.

# %%
my_other_dictionary = {"b":203,"c":"a","a":400,"d":"f"}

# %%
# Answer
if "a" in my_other_dictionary.keys():
    print("a is found")
# Out:
# a is found

# %% [markdown]
# # 6) Write a code that prints only the even numbers from the list below.nız.

# %%
my_numbers = [1,2,3,4,5,6,19,20,32,21,20,1111,23,24]

# %%
# Answer
for element in my_numbers:
    if element % 2 == 0:
        print(f"{element} is even")
    else:
        print(f"{element} is odd")
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 19 is odd
# 20 is even
# 32 is even
# 21 is odd
# 20 is even
# 1111 is odd
# 23 is odd
# 24 is even

# %%
# Answer

# %%
# Answer

# %% [markdown]
# # 7) The numbers in the list below represent the radius of a circle.

# %%
#Create another new list containing the circumference of all circles. (Hint: 2 * pi * r)  Pi can be taken as 3.14.

# %%
r_list = [3,2,5,8,4,6,9,12]

# %%
# Answer
new_r_list = [2 * 3.14 * r for r in r_list]
new_r_list
# Out:
# [18.84, 12.56, 31.400000000000002, 50.24, 25.12, 37.68, 56.52, 75.36]

# %%
# Answer

# %%
# Answer

# %% [markdown]
# # 8) The following list contains structures with name-age matches.

# %%
# Create a new, separate list containing only ages.

# %%
age_name_list = [("Ahmet",30),("Ayse",24),("Mehmet",40),("Fatma",29)]

# %%
# Answer
age_list=[age for name, age in age_name_list]
age_list
# Out:
# [30, 24, 40, 29]

# %%
# Answer

# %%
# Answer

# %% [markdown]
# # 9) Write a code that randomly selects one of the following music groups.

# %%
metal_list = ["Metallica","Iron Maiden","Dream Theater","Megadeth","AC/DC"]

# %%
# Answer
import random
random_metal = random.choice(metal_list)
print(random_metal)
# Out:
# Metallica

# %%
# Answer

# %%
# Answer

# %% [markdown]
# # 10) What will be the output of the following code?

# %%
number_list = [5,7,18,21,20,10,405,24]

# %% [markdown]
# [num % 2 == 0 for num in number_list]

# %%
# Answer
[False, False, True, False, True, True, False, True]
# Out:
# [False, False, True, False, True, True, False, True]

# %%
# Answer

# %%
# Answer
