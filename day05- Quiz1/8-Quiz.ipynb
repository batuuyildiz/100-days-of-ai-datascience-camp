# %% [markdown]
# # 1) Assign the 5th character of the following string to a variable.

# %%
my_string = "Python Ogreniyorum"

# %%
#Answer
fifth_character = my_string[4]  # Indexing starts at 0, so the 5th character is at index 4
fifth_character
# Out:
# 'o'

# %%
#Answer

# %% [markdown]
# # 2) Print all characters between the 5th and 8th characters of the following string (including the 5th and 8th characters).

# %%
my_new_string = "ProgramlamayaMerhabaDedik"

# %%
#Answer
my_new_string[4:8]  # Slicing from index 4 to 8 (8 is not included)
# Out:
# 'raml'

# %%
#Answer

# %% [markdown]
# # 3) Write the following string backwards using code.

# %%
my_last_string = "Afyonkarahisarlilastiramadiklarimizdanmisiniz"

# %%
#Answer
my_last_string[::-1]  # Slicing with a step of -1 to reverse the string
# Out:
# 'zinisimnadzimiralkidamaritsalilrasiharaknoyfA'

# %%
#Answer

# %% [markdown]
# # 4) What data type will be the result of the following operation?

# %% [markdown]
# 4 + 12.2 + 48

# %%
#Answer
type(4+12.2+48)
# Out:
# float

# %%
#Answer

# %% [markdown]
# # 5) What is the result of the following operation?

# %% [markdown]
# 5 + 7 * 12

# %%
#Answer
5+7*12
# Out:
# 89

# %%
#Answer

# %% [markdown]
# # 6) Create this list in at least two different ways: [1,3,“a”]

# %%
#Answer
firs_List= [1,3,"a"]
second_List=  list()
second_List.append(1)
second_List.append(3)
second_List.append("a") 
print   (firs_List)
second_List
# Out:
# [1, 3, 'a']
# [1, 3, 'a']

# %%
#Answer

# %%
#Answer

# %% [markdown]
# # 7) Take the following “b” in a single line:

# %%
my_list = [3.14,4,[2,3,"b"],True]

# %%
#Answer
my_list[2][2]   # Accessing the string "b" in the nested list
# Out:
# 'b'

# %%
#Answer

# %%
#Answer

# %% [markdown]
# # 8) Take the following “a” in a single line:

# %%
my_dictionary = {"key1":20.25, "kk2":[40,{"k21":"a"}]}

# %%
#Answer
my_dictionary["kk2"][1]["k21"]  # Accessing the value "a" in the nested dictionary
# Out:
# 'a'

# %%
#Answer

# %% [markdown]
# # 9) When the following list is converted to a set, which values will remain?

# %%
my_list_to_be_set = [3,4,9,3,21,22,4,3,9,10,21,22]

# %%
#Answer
my_list_to_be_set = set(my_list_to_be_set)  # Convert list to set to remove duplicates
my_list_to_be_set
# Out:
# {3, 4, 9, 10, 21, 22}

# %%
#Answer

# %% [markdown]
# # 10) What will be the result of the following expression?

# %%
x = 30 * 5 + 3

# %%
y = 108 - 2 * 4

# %% [markdown]
# x > y

# %%
#Answer
(x>y)
# Out:
# True

# %%
#Answer

# %%
#Answer
