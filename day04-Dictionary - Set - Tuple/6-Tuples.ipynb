# %% [markdown]
# # Tuples

# %%
myList =   [10, "b", "bvbv", 3.14, 5]  # Example list

# %%
myList[0]
# Out:
# 10

# %%
myList
# Out:
# [10, 'b', 'bvbv', 3.14, 5]

# %%
myTuple = (10, "b", "bvbv", 3.14, 5)  # Example tuple

# %%
myTuple [0]  # Accessing the first element of the tuple
# Out:
# 10

# %%
# myTuple [0] = 100  # Attempting to change the first element of the tuple (will raise an error)

# %%
# immutable!!

# %%
myTuple.index(10)  # Finding the index of the first occurrence of 10 in the tuple
# Out:
# 0

# %%
myTuple.count("b")
# Out:
# 1

# %%
#
