# %% [markdown]
# # Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBool = True  # Assigning a boolean value to a variable

# %%
type(myBool)
# Out:
# bool

# %%
3<5
# Out:
# True

# %%
2>5
# Out:
# False

# %%
age=input("Enter your age: ")
print("Your age is:", x)
if int(age)<18:
    print("You are a minor.")
else:
    print("You are an adult.")
# Out:
# Your age is: 30
# You are an adult.
